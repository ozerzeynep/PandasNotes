# %%
import pandas as pd

# %%
df = pd.read_excel("starbucks.xlsx")

# %%
df.head(3)
# Out:
#                 item  calories fat  carb  fiber  protein    type
# 0       8-Grain Roll       350   8    67      5       10  bakery
# 1  Apple Bran Muffin       350   9    64      7        6  bakery
# 2      Apple Fritter       420  20    59      0        5  bakery

# %%
df.tail(3)
# Out:
#                                      item  calories                  fat  \
# 74             Greek Yogurt Honey Parfait       300                   12
# 75         Peach Raspberry Yogurt Parfait       300                    4
# 76  Strawberry & Blueberry Yogurt Parfait       300  2024-05-03 00:00:00
#
#     carb  fiber  protein     type
# 74    44      0        8  parfait
# 75    57      3       10  parfait
# 76    60      3        7  parfait

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   item      77 non-null     object
#  1   calories  77 non-null     int64
#  2   fat       77 non-null     object
#  3   carb      77 non-null     int64
#  4   fiber     77 non-null     int64
#  5   protein   77 non-null     int64
#  6   type      77 non-null     object
# dtypes: int64(4), object(3)
# memory usage: 4.3+ KB

# %%
df.columns
# Out:
# Index(['item', 'calories', 'fat', 'carb', 'fiber', 'protein', 'type'], dtype='object')

# %%
df.shape
# Out:
# (77, 7)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=77, step=1)

# %%
df.describe().T
# Out:
#           count        mean         std   min    25%    50%    75%    max
# calories   77.0  338.831169  105.368701  80.0  300.0  350.0  420.0  500.0
# carb       77.0   44.870130   16.551634  16.0   31.0   45.0   59.0   80.0
# fiber      77.0    2.220779    2.112764   0.0    0.0    2.0    4.0    7.0
# protein    77.0    9.480519    8.079556   0.0    5.0    7.0   15.0   34.0

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isnull()
# Out:
#      item  calories    fat   carb  fiber  protein   type
# 0   False     False  False  False  False    False  False
# 1   False     False  False  False  False    False  False
# 2   False     False  False  False  False    False  False
# 3   False     False  False  False  False    False  False
# 4   False     False  False  False  False    False  False
# ..    ...       ...    ...    ...    ...      ...    ...
# 72  False     False  False  False  False    False  False
# 73  False     False  False  False  False    False  False
# 74  False     False  False  False  False    False  False
# 75  False     False  False  False  False    False  False
# 76  False     False  False  False  False    False  False
#
# [77 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# item        0
# calories    0
# fat         0
# carb        0
# fiber       0
# protein     0
# type        0
# dtype: int64

# %%
df['protein'].head(3)
# Out:
# 0    10
# 1     6
# 2     5
# Name: protein, dtype: int64

# %%
df['item'].head()
# Out:
# 0                   8-Grain Roll
# 1              Apple Bran Muffin
# 2                  Apple Fritter
# 3                Banana Nut Loaf
# 4    Birthday Cake Mini Doughnut
# Name: item, dtype: object

# %%
df['type'].value_counts()
# Out:
# type
# bakery           41
# petite            9
# bistro box        8
# hot breakfast     8
# sandwich          7
# parfait           3
# salad             1
# Name: count, dtype: int64

# %%
df = df.drop(1, axis=0)

# %%
df.head(3)
# Out:
#               item  calories  carb  fiber  protein    type
# 0     8-Grain Roll       350    67      5       10  bakery
# 2    Apple Fritter       420    59      0        5  bakery
# 3  Banana Nut Loaf       490    75      4        7  bakery

# %%
"carb" in df
# Out:
# True

# %%
"protein" in df
# Out:
# True

# %%
"fat" in df
# Out:
# False

# %%
type(df['protein'])
# Out:
# pandas.core.series.Series

# %%
type(df[['protein']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['type', 'calories']]
# Out:
#         type  calories
# 0     bakery       350
# 2     bakery       420
# 3     bakery       490
# 4     bakery       130
# 5     bakery       370
# ..       ...       ...
# 72  sandwich       420
# 73  sandwich       390
# 74   parfait       300
# 75   parfait       300
# 76   parfait       300
#
# [76 rows x 2 columns]

# %%
df.iloc[0:4]
# Out:
#                           item  calories  carb  fiber  protein    type
# 0                 8-Grain Roll       350    67      5       10  bakery
# 2                Apple Fritter       420    59      0        5  bakery
# 3              Banana Nut Loaf       490    75      4        7  bakery
# 4  Birthday Cake Mini Doughnut       130    17      0        0  bakery

# %%
df.loc[0:4]
# Out:
#                           item  calories  carb  fiber  protein    type
# 0                 8-Grain Roll       350    67      5       10  bakery
# 2                Apple Fritter       420    59      0        5  bakery
# 3              Banana Nut Loaf       490    75      4        7  bakery
# 4  Birthday Cake Mini Doughnut       130    17      0        0  bakery

# %%
df.loc[0:4, "item"]
# Out:
# 0                   8-Grain Roll
# 2                  Apple Fritter
# 3                Banana Nut Loaf
# 4    Birthday Cake Mini Doughnut
# Name: item, dtype: object

# %%
df.loc[0:5, "type"]
# Out:
# 0    bakery
# 2    bakery
# 3    bakery
# 4    bakery
# 5    bakery
# Name: type, dtype: object

# %%
df[df["calories"] > 450].head()
# Out:
#                       item  calories  carb  fiber  protein    type
# 3          Banana Nut Loaf       490    75      4        7  bakery
# 6          Blueberry Scone       460    61      2        7  bakery
# 15     Cinnamon Chip Scone       480    70      3        7  bakery
# 16  Cranberry Orange Scone       490    73      2        8  bakery
# 21   Iced Lemon Pound Cake       490    67      0        5  bakery

# %%
df['calories'].max()
# Out:
# 500

# %%
df['calories'].min()
# Out:
# 80

# %%
df[df['protein'] <= 6].head()
# Out:
#                           item  calories  carb  fiber  protein    type
# 2                Apple Fritter       420    59      0        5  bakery
# 4  Birthday Cake Mini Doughnut       130    17      0        0  bakery
# 5            Blueberry Oat Bar       370    47      5        6  bakery
# 7   Bountiful Blueberry Muffin       370    55      0        6  bakery
# 8            Butter Croissant        310    32      0        5  bakery

# %%
df['protein'].max()
# Out:
# 34

# %%
df[df['calories'] >= 400]['calories'].count()
# Out:
# 24

# %%
df.loc[df['calories'] >=470, ["item", "type"]].head(4)
# Out:
#                       item    type
# 3          Banana Nut Loaf  bakery
# 15     Cinnamon Chip Scone  bakery
# 16  Cranberry Orange Scone  bakery
# 21   Iced Lemon Pound Cake  bakery

# %%
df.loc[df['protein'] <5, ["type", "item", "carb"]].head(4)
# Out:
#       type                         item  carb
# 4   bakery  Birthday Cake Mini Doughnut    17
# 10  bakery       Chocolate Chunk Cookie    51
# 18  bakery   Double Fudge Mini Doughnut    16
# 20  bakery       Ginger Molasses Cookie    58

# %%
df.loc[(df['protein'] < 10) & (df['calories'] >=450), ["item", "type"]].head()
# Out:
#                       item    type
# 3          Banana Nut Loaf  bakery
# 6          Blueberry Scone  bakery
# 15     Cinnamon Chip Scone  bakery
# 16  Cranberry Orange Scone  bakery
# 21   Iced Lemon Pound Cake  bakery

# %%
df['calories'].mean()
# Out:
# 338.6842105263158

# %%
df['protein'].mean()
# Out:
# 9.526315789473685

# %%
df.groupby("type")["protein"].mean()
# Out:
# type
# bakery            5.925000
# bistro box       19.125000
# hot breakfast    16.125000
# parfait           8.333333
# petite            1.111111
# salad             0.000000
# sandwich         24.285714
# Name: protein, dtype: float64

# %%
df.groupby("type")["calories"].mean()
# Out:
# type
# bakery           369.250000
# bistro box       377.500000
# hot breakfast    325.000000
# parfait          300.000000
# petite           177.777778
# salad             80.000000
# sandwich         395.714286
# Name: calories, dtype: float64

# %%
df.pivot_table("calories", "protein", "fiber").head()
# Out:
# fiber             0      2      3      4   5   6
# protein
# 0        166.250000   80.0    NaN    NaN NaN NaN
# 2        176.000000    NaN    NaN    NaN NaN NaN
# 3        360.000000    NaN    NaN    NaN NaN NaN
# 4        425.000000  360.0    NaN    NaN NaN NaN
# 5        406.666667  360.0  370.0  270.0 NaN NaN

# %%
df.pivot_table("calories", "protein", "fiber", aggfunc="std").head()
# Out:
# fiber            0          2         3           4   6
# protein
# 0        30.207615        NaN       NaN         NaN NaN
# 2        11.401754        NaN       NaN         NaN NaN
# 4         7.071068  28.284271       NaN         NaN NaN
# 5        90.737717  84.852814       NaN  183.847763 NaN
# 6        47.258156  66.583281  63.63961         NaN NaN

# %%
ogrenciler = pd.DataFrame({
    'ogrenci_id': [1, 2, 3, 4],
    'isim': ['Ahmet', 'Ayşe', 'Ali', 'Fatma'],
    'yas': [20, 21, 19, 22]
})

# %%
notlar = pd.DataFrame({
    'ogrenci_id': [1, 2, 3, 4],
    'ders': ['Matematik', 'Fizik', 'Kimya', 'Biyoloji'],
    'not': [95, 88, 76, 85]
})

# %%
birlesmis = pd.merge(ogrenciler, notlar, on='ogrenci_id')

# %%
print(birlesmis)
# Out:
#    ogrenci_id   isim  yas       ders  not
# 0           1  Ahmet   20  Matematik   95
# 1           2   Ayşe   21      Fizik   88
# 2           3    Ali   19      Kimya   76
# 3           4  Fatma   22   Biyoloji   85

# %%
df.nunique()
# Out:
# item        76
# calories    29
# carb        48
# fiber        6
# protein     26
# type         7
# dtype: int64

# %%
df['type'].nunique()
# Out:
# 7

# %%
df[['type','item']].nunique()
# Out:
# type     7
# item    76
# dtype: int64

# %%
type(df[["calories"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df["calories"] = df["calories"].astype("int32")

# %%
df[df["type"] == "bakery"].head(3)
# Out:
#               item  calories  carb  fiber  protein    type
# 0     8-Grain Roll       350    67      5       10  bakery
# 2    Apple Fritter       420    59      0        5  bakery
# 3  Banana Nut Loaf       490    75      4        7  bakery

# %%
df[df["type"] == "parfait"].head(3)
# Out:
#                                      item  calories  carb  fiber  protein  \
# 74             Greek Yogurt Honey Parfait       300    44      0        8
# 75         Peach Raspberry Yogurt Parfait       300    57      3       10
# 76  Strawberry & Blueberry Yogurt Parfait       300    60      3        7
#
#        type
# 74  parfait
# 75  parfait
# 76  parfait

# %%
df[df["type"] == "salad"].head()
# Out:
#                   item  calories  carb  fiber  protein   type
# 66  Deluxe Fruit Blend        80    20      2        0  salad

# %%
df[df["type"] != "salad"].head()
# Out:
#                           item  calories  carb  fiber  protein    type
# 0                 8-Grain Roll       350    67      5       10  bakery
# 2                Apple Fritter       420    59      0        5  bakery
# 3              Banana Nut Loaf       490    75      4        7  bakery
# 4  Birthday Cake Mini Doughnut       130    17      0        0  bakery
# 5            Blueberry Oat Bar       370    47      5        6  bakery

# %%
df[df["type"] != "bakery"].head(3)
# Out:
#                      item  calories  carb  fiber  protein        type
# 41         Cheese & Fruit       480    39      6       18  bistro box
# 42       Chicken & Hummus       270    29      6       16  bistro box
# 43  Chicken Lettuce Wraps       360    32      4       17  bistro box

# %%
df.head(3)
# Out:
#               item  calories  carb  fiber  protein    type
# 0     8-Grain Roll       350    67      5       10  bakery
# 2    Apple Fritter       420    59      0        5  bakery
# 3  Banana Nut Loaf       490    75      4        7  bakery

# %%
df[(df['calories'] >= 365) | (df["protein"] <= 6)].head()
# Out:
#                           item  calories  carb  fiber  protein    type
# 2                Apple Fritter       420    59      0        5  bakery
# 3              Banana Nut Loaf       490    75      4        7  bakery
# 4  Birthday Cake Mini Doughnut       130    17      0        0  bakery
# 5            Blueberry Oat Bar       370    47      5        6  bakery
# 6              Blueberry Scone       460    61      2        7  bakery

# %%
df[(df['calories'] >= 365) & (df["protein"] <= 6)].head()
# Out:
#                                 item  calories  carb  fiber  protein    type
# 2                      Apple Fritter       420    59      0        5  bakery
# 5                  Blueberry Oat Bar       370    47      5        6  bakery
# 7         Bountiful Blueberry Muffin       370    55      0        6  bakery
# 10            Chocolate Chunk Cookie       380    51      2        4  bakery
# 13  Chocolate Old-Fashioned Doughnut       420    57      2        5  bakery

# %%
df.groupby(["carb", "protein"]).agg({"calories": ["sum", "count", "mean"]}).tail()
# Out:
#              calories
#                   sum count   mean
# carb protein
# 70   7            480     1  480.0
# 73   8            490     1  490.0
# 75   7            490     1  490.0
# 78   6            480     1  480.0
# 80   5            400     1  400.0

# %%
df.sort_values("calories", ascending=True).head(6)
# Out:
#                            item  calories  carb  fiber  protein           type
# 66           Deluxe Fruit Blend        80    20      2        0          salad
# 18   Double Fudge Mini Doughnut       130    16      0        0         bakery
# 4   Birthday Cake Mini Doughnut       130    17      0        0         bakery
# 30    Petite Vanilla Bean Scone       140    21      0        0         bakery
# 63    Starbucks Perfect Oatmeal       140    25      4        5  hot breakfast
# 55   Raspberry Truffle Cake Pop       160    24      0        2         petite

# %%
df.sort_values("calories", ascending=False)[:10]
# Out:
#                                             item  calories  carb  fiber  \
# 61  Sausage & Cheddar Classic Breakfast Sandwich       500    41      0
# 21                         Iced Lemon Pound Cake       490    67      0
# 3                                Banana Nut Loaf       490    75      4
# 40                       Zucchini Walnut Muffin        490    52      2
# 16                        Cranberry Orange Scone       490    73      2
# 41                                Cheese & Fruit       480    39      6
# 15                           Cinnamon Chip Scone       480    70      3
# 34                               Raspberry Scone       480    59      3
# 33                                Pumpkin Scone        480    78      2
# 6                                Blueberry Scone       460    61      2
#
#     protein           type
# 61       19  hot breakfast
# 21        5         bakery
# 3         7         bakery
# 40        7         bakery
# 16        8         bakery
# ...
